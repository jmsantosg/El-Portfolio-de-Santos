# %%
import pandas as pd

# %%
pd.read_csv('./../dataset/salaries.csv')
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT              Data Engineer
# 1          2023               SE              FT              Data Engineer
# 2          2023               SE              FT          Research Engineer
# 3          2023               SE              FT          Research Engineer
# 4          2023               SE              FT  Machine Learning Engineer
# ...         ...              ...             ...                        ...
# 2668       2020               SE              FT             Data Scientist
# 2669       2021               MI              FT   Principal Data Scientist
# 2670       2020               EN              FT             Data Scientist
# 2671       2020               EN              CT      Business Data Analyst
# 2672       2021               SE              FT       Data Science Manager
#
# ...
